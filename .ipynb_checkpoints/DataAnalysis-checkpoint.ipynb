# %% [markdown]
# # Part I: Departmental and Policy Data Analysis

# %% [markdown]
# Goal: Calculate correlation between numPolicies and numkillings and calculate correlation per policy with numkillings.
#
# Step 1: Read and clean data (sidenote: the most  time consuming part of this entire project was getting the policy data, converting it using Optical Character Recognition Software, and then formatting that into the same CSV file)

# %%
import csv
import numpy as np


#read CSV
with open('policydept.csv') as csvfile:
    csvthing = csv.reader(csvfile, delimiter=',')
    total=0
    count=0
    readCSV=[]
    for row in csvthing:
        readCSV.append(row)

    #dictify row 1
    querydict={}
    labels=readCSV[0]
    for el in labels:
        name=el
        querydict[name]=count
        count=count+1
    count=0

    #dictify column 1
    deptdict={}
    for row in readCSV:
        if row[0]!='City':
            dept=row[0]
            deptdict[dept]=count
            count=count+1
    count=0
    
    print(deptdict)
    print(querydict)
# Out:
# {'Albuquerque': 0, 'Anaheim': 1, 'Anchorage': 2, 'Arlington': 3, 'Atlanta': 4, 'Aurora': 5, 'Austin': 6, 'Bakersfield': 7, 'Baltimore': 8, 'Baton Rouge': 9, 'Boston': 10, 'Buffalo': 11, 'Chandler': 12, 'Charlotte': 13, 'Chicago': 14, 'Chula Vista': 15, 'Cincinnati': 16, 'Cleveland': 17, 'Columbus': 18, 'Corpus Christi': 19, 'Dallas': 20, 'Denver': 21, 'Detroit': 22, 'Durham': 23, 'Fort Worth': 24, 'Fremont': 25, 'Fresno': 26, 'Garland': 27, 'Glendale': 28, 'Greensboro': 29, 'Henderson': 30, 'Honolulu': 31, 'Houston': 32, 'Indianapolis': 33, 'Irvine': 34, 'Irving': 35, 'Jacksonville': 36, 'Kansas City Missouri': 37, 'Laredo': 38, 'Las Vegas': 39, 'Lexington': 40, 'Lincoln': 41, 'Los Angeles': 42, 'Louisville': 43, 'Lubbock': 44, 'Madison': 45, 'Mesa': 46, 'Miami': 47, 'Milwaukee': 48, 'Minneapolis': 49, 'Nashville': 50, 'New Orleans': 51, 'New York': 52, 'Newark': 53, 'Norfolk': 54, 'North Las Vegas': 55, 'Oakland': 56, 'Oklahoma City': 57, 'Omaha': 58, 'Orlando': 59, 'Philadelphia': 60, 'Phoenix': 61, 'Pittsburgh': 62, 'Plano': 63, 'Portland': 64, 'Raleigh': 65, 'Reno': 66, 'Riverside': 67, 'Rochester': 68, 'San Antonio': 69, 'San Bernardino': 70, 'San Diego': 71, 'San Francisco': 72, 'San Jose': 73, 'Santa Ana': 74, 'Scottsdale': 75, 'Seattle': 76, 'Spokane': 77, 'St. Louis': 78, 'St. Paul': 79, 'St. Petersburg': 80, 'Stockton': 81, 'Tampa': 82, 'Toledo': 83, 'Tucson': 84, 'Tulsa': 85, 'Virginia Beach': 86, 'Washington': 87, 'Wichita': 88, 'Winston-Salem': 89}
# {'City': 0, 'PD': 1, 'Black People Killed by Police (1/1/2013-12/31/2018)': 2, 'Hispanic People Killed by Police (1/1/2013-12/31/2018)': 3, 'Native American People Killed by Police (1/1/2013-12/31/2018)': 4, 'Asian People Killed by Police (1/1/2013-12/31/2018)': 5, 'Pacific Islanders Killed by Police (1/1/2013-12/31/2018)': 6, 'White People Killed by Police (1/1/2013-12/31/2018)': 7, 'Unknown Race People Killed by Police (1/1/2013-12/31/2018)': 8, 'All People Killed by Police (1/1/2013-12/31/2018)': 9, 'Total': 10, 'Black': 11, 'White': 12, 'Amer. Indian': 13, 'Asian': 14, 'Hawaiian': 15, 'Asian/Pacific Islander': 16, 'Other': 17, 'Two or\nmore races': 18, 'Hispanic': 19, 'Population': 20, 'Black-White Dissimilarity Index (2010)': 21, 'Violent\ncrime': 22, 'Murder and\nnonnegligent manslaughter': 23, 'Violent Crime Rate': 24, 'Murder Rate': 25, 'Avg Annual Police Homicide Rate': 26, 'Avg Annual Police Homicide Rate for Black People': 27, 'Avg Annual Police Homicide Rate for White People': 28, 'Avg Annual Police Homicide Rate for Hispanic People': 29, 'Black-White Disparity': 30, 'Hispanic-White Disparity': 31, 'reqDe_esc': 32, 'banChoke&Stanglehold': 33, 'duty2intervene': 34, 'warnb4shoot': 35, 'cantShootVehicles': 36, 'reqCompRep': 37, 'reqExhOthMeans': 38, 'forceContinuum': 39, 'numPolicies': 40, 'killings': 41, 'killingsPerMillion': 42}

# %% [markdown]
# ## Correlation with Number of Policies

# %% [markdown]
# Getting data from the CSV file about policies, and police homicide rates

# %%
nps=[]
rates=[]
ratebs=[]
disps=[]
for dept in deptdict.keys():
    print('dept is', dept)
    i=deptdict[dept]+1
    j=querydict['numPolicies']
    nP=int(readCSV[i][j])
    nps.append(nP)
    print('numPolicies is', nP)
    j=querydict['killingsPerMillion']
    rate=float(readCSV[i][j])
    rates.append(rate)
    rateb=float(readCSV[i][querydict['Avg Annual Police Homicide Rate for Black People']])
    ratebs.append(rateb)
    print('police homicide rate is', rate)
    disp=float(readCSV[i][querydict['Black-White Disparity']])+float(readCSV[i][querydict['Hispanic-White Disparity']])
    disps.append(disp)
    print(disp)
    print()
# Out:
# dept is Albuquerque
# numPolicies is 5
# police homicide rate is 9.2
# 5.28
#
# dept is Anaheim
# numPolicies is 3
# police homicide rate is 17.8
# 12.29
#
# dept is Anchorage
# numPolicies is 3
# police homicide rate is 10.3
# 2.07
#
# dept is Arlington
# numPolicies is 5
# police homicide rate is 8.2
# 5.4399999999999995
#
# dept is Atlanta
# numPolicies is 2
# police homicide rate is 9.5
# 6.79
#
# dept is Aurora
# numPolicies is 3
# police homicide rate is 18.5
# 3.4299999999999997
#
# dept is Austin
# numPolicies is 3
# police homicide rate is 12.7
# 2.04
#
# dept is Bakersfield
# numPolicies is 1
# police homicide rate is 20.1
# 5.27
#
# dept is Baltimore
# numPolicies is 2
# police homicide rate is 12.9
# 3.84
#
# dept is Baton Rouge
# numPolicies is 2
# police homicide rate is 13.1
# 40.0
#
# dept is Boston
# numPolicies is 4
# police homicide rate is 4.9
# 40.0
#
# dept is Buffalo
# numPolicies is 3
# police homicide rate is 0.0
# 11.16
#
# dept is Chandler
# numPolicies is 3
# police homicide rate is 8.5
# 2.81
#
# dept is Charlotte
# numPolicies is 2
# police homicide rate is 8.2
# 4.6899999999999995
#
# dept is Chicago
# numPolicies is 3
# police homicide rate is 5.2
# 33.04
#
# dept is Chula Vista
# numPolicies is 2
# police homicide rate is 0.0
# 0.35
#
# dept is Cincinnati
# numPolicies is 5
# police homicide rate is 20.2
# 8.61
#
# dept is Cleveland
# numPolicies is 5
# police homicide rate is 5.0
# 5.1
#
# dept is Columbus
# numPolicies is 3
# police homicide rate is 12.7
# 5.07
#
# dept is Corpus Christi
# numPolicies is 5
# police homicide rate is 6.6
# 10.76
#
# dept is Dallas
# numPolicies is 3
# police homicide rate is 5.8
# 2.13
#
# dept is Denver
# numPolicies is 4
# police homicide rate is 11.7
# 2.88
#
# dept is Detroit
# numPolicies is 4
# police homicide rate is 1.4
# 40.0
#
# dept is Durham
# numPolicies is 2
# police homicide rate is 4.4
# 11.75
#
# dept is Fort Worth
# numPolicies is 2
# police homicide rate is 8.1
# 2.9
#
# dept is Fremont
# numPolicies is 2
# police homicide rate is 9.3
# 40.0
#
# dept is Fresno
# numPolicies is 1
# police homicide rate is 14.2
# 3.06
#
# dept is Garland
# numPolicies is 1
# police homicide rate is 8.8
# 2.59
#
# dept is Glendale
# numPolicies is 2
# police homicide rate is 8.8
# 5.3100000000000005
#
# dept is Greensboro
# numPolicies is 1
# police homicide rate is 3.7
# 2.27
#
# dept is Henderson
# numPolicies is 4
# police homicide rate is 3.9
# 1.54
#
# dept is Honolulu
# numPolicies is 3
# police homicide rate is 5.9
# 2.29
#
# dept is Houston
# numPolicies is 1
# police homicide rate is 7.6
# 6.15
#
# dept is Indianapolis
# numPolicies is 1
# police homicide rate is 13.4
# 2.55
#
# dept is Irvine
# numPolicies is 3
# police homicide rate is 0.0
# 40.0
#
# dept is Irving
# numPolicies is 0
# police homicide rate is 9.2
# 3.36
#
# dept is Jacksonville
# numPolicies is 3
# police homicide rate is 9.7
# 2.81
#
# dept is Kansas City Missouri
# numPolicies is 0
# police homicide rate is 6.5
# 4.64
#
# dept is Laredo
# numPolicies is 3
# police homicide rate is 8.5
# 0.25
#
# dept is Las Vegas
# numPolicies is 4
# police homicide rate is 6.4
# 2.5
#
# dept is Lexington
# numPolicies is 3
# police homicide rate is 0.0
# 1.7
#
# dept is Lincoln
# numPolicies is 4
# police homicide rate is 7.7
# 22.51
#
# dept is Los Angeles
# numPolicies is 3
# police homicide rate is 8.7
# 6.02
#
# dept is Louisville
# numPolicies is 5
# police homicide rate is 3.3
# 4.53
#
# dept is Lubbock
# numPolicies is 1
# police homicide rate is 0.0
# 5.21
#
# dept is Madison
# numPolicies is 4
# police homicide rate is 8.6
# 5.35
#
# dept is Mesa
# numPolicies is 2
# police homicide rate is 15.9
# 1.31
#
# dept is Miami
# numPolicies is 6
# police homicide rate is 10.0
# 40.0
#
# dept is Milwaukee
# numPolicies is 3
# police homicide rate is 3.4
# 11.33
#
# dept is Minneapolis
# numPolicies is 1
# police homicide rate is 5.2
# 24.7
#
# dept is Nashville
# numPolicies is 3
# police homicide rate is 5.0
# 7.74
#
# dept is New Orleans
# numPolicies is 6
# police homicide rate is 11.6
# 1.79
#
# dept is New York
# numPolicies is 5
# police homicide rate is 2.0
# 6.91
#
# dept is Newark
# numPolicies is 4
# police homicide rate is 7.2
# 1.97
#
# dept is Norfolk
# numPolicies is 21
# police homicide rate is 20.6
# 1.47
#
# dept is North Las Vegas
# numPolicies is 1
# police homicide rate is 9.2
# 2.4299999999999997
#
# dept is Oakland
# numPolicies is 5
# police homicide rate is 12.8
# 6.65
#
# dept is Oklahoma City
# numPolicies is 2
# police homicide rate is 20.7
# 7.109999999999999
#
# dept is Omaha
# numPolicies is 2
# police homicide rate is 14.7
# 3.8
#
# dept is Orlando
# numPolicies is 1
# police homicide rate is 25.2
# 5.53
#
# dept is Philadelphia
# numPolicies is 7
# police homicide rate is 2.6
# 4.37
#
# dept is Phoenix
# numPolicies is 3
# police homicide rate is 12.5
# 3.74
#
# dept is Pittsburgh
# numPolicies is 2
# police homicide rate is 6.5
# 12.57
#
# dept is Plano
# numPolicies is 5
# police homicide rate is 0.0
# 3.97
#
# dept is Portland
# numPolicies is 3
# police homicide rate is 5.1
# 4.81
#
# dept is Raleigh
# numPolicies is 5
# police homicide rate is 2.5
# 5.57
#
# dept is Reno
# numPolicies is 0
# police homicide rate is 17.8
# 20.84
#
# dept is Riverside
# numPolicies is 3
# police homicide rate is 0.0
# 40.0
#
# dept is Rochester
# numPolicies is 1
# police homicide rate is 9.5
# 2.85
#
# dept is San Antonio
# numPolicies is 3
# police homicide rate is 7.5
# 5.08
#
# dept is San Bernardino
# numPolicies is 4
# police homicide rate is 14.3
# 0.53
#
# dept is San Diego
# numPolicies is 2
# police homicide rate is 6.9
# 2.1
#
# dept is San Francisco
# numPolicies is 3
# police homicide rate is 12.4
# 9.24
#
# dept is San Jose
# numPolicies is 1
# police homicide rate is 8.5
# 4.630000000000001
#
# dept is Santa Ana
# numPolicies is 2
# police homicide rate is 12.3
# 5.3
#
# dept is Scottsdale
# numPolicies is 2
# police homicide rate is 4.6
# 15.43
#
# dept is Seattle
# numPolicies is 6
# police homicide rate is 6.6
# 4.92
#
# dept is Spokane
# numPolicies is 3
# police homicide rate is 14.4
# 3.78
#
# dept is St. Louis
# numPolicies is 4
# police homicide rate is 18.8
# 8.33
#
# dept is St. Paul
# numPolicies is 7
# police homicide rate is 17.5
# 5.12
#
# dept is St. Petersburg
# numPolicies is 6
# police homicide rate is 4.1
# 0.68
#
# dept is Stockton
# numPolicies is 0
# police homicide rate is 24.0
# 3.99
#
# dept is Tampa
# numPolicies is 1
# police homicide rate is 11.9
# 2.5
#
# dept is Toledo
# numPolicies is 2
# police homicide rate is 3.5
# 1.38
#
# dept is Tucson
# numPolicies is 3
# police homicide rate is 11.5
# 3.46
#
# dept is Tulsa
# numPolicies is 3
# police homicide rate is 7.7
# 1.79
#
# dept is Virginia Beach
# numPolicies is 4
# police homicide rate is 4.6
# 6.79
#
# dept is Washington
# numPolicies is 7
# police homicide rate is 6.6
# 10.44
#
# dept is Wichita
# numPolicies is 3
# police homicide rate is 5.2
# 2.64
#
# dept is Winston-Salem
# numPolicies is 4
# police homicide rate is 4.4
# 4.16

# %% [markdown]
# As shown below there isn't the greatest negative correlation between number of policies and rate of killings. This could be due to varied crime rates and implementation of policies. I decided it might be better to look at individual policies

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('fivethirtyeight')

plt.scatter(nps,ratebs)
np.corrcoef(nps,ratebs)
# Out:
# array([[ 1.        , -0.13237558],
#        [-0.13237558,  1.        ]])

# %% [markdown]
# Looking at individual policies still didn't show the most correlation either. This made me realize that there was an even bigger problem.

# %%
for j in range(32,41):
    policys=[]
    print(readCSV[0][j])
    for dept in deptdict.keys():
        i=deptdict[dept]+1
        nP=int(readCSV[i][j])
        policys.append(nP)
    plt.scatter(policys,ratebs)
    print(np.corrcoef(policys,ratebs))
# Out:
# reqDe_esc
# [[ 1.         -0.12887582]
#  [-0.12887582  1.        ]]
# banChoke&Stanglehold
# [[ 1.         -0.14752721]
#  [-0.14752721  1.        ]]
# duty2intervene
# [[1.         0.03284774]
#  [0.03284774 1.        ]]
# warnb4shoot
# [[1.         0.05944271]
#  [0.05944271 1.        ]]
# cantShootVehicles
# [[ 1.         -0.08399328]
#  [-0.08399328  1.        ]]
# reqCompRep
# [[ 1.         -0.13546126]
#  [-0.13546126  1.        ]]
# reqExhOthMeans
# [[ 1.         -0.21934268]
#  [-0.21934268  1.        ]]
# forceContinuum
# [[ 1.         -0.09846554]
#  [-0.09846554  1.        ]]
# numPolicies
# [[ 1.         -0.13237558]
#  [-0.13237558  1.        ]]

# %% [markdown]
# I then restricted to similar cities to avoid noise due to differing factors. I thought it would be ideal to compare a city to itself before the policy but I didn't have that data so I had to use similar cities. As shown below, this effectively revealed that policies really did correlate to lower rates of police homicide.

# %%
def lookAtCities(bigcities,s):
    ratesrestricted=[]
    for dept in bigcities:
        i=deptdict[dept]+1
        query='Avg Annual Police Homicide Rate'+s
        j=querydict[query]
        rate=float(readCSV[i][j])
        ratesrestricted.append(rate)
    for j in range(32,40):
        policys=[]
        print(readCSV[0][j])
        for dept in bigcities:
            i=deptdict[dept]+1
            nP=int(readCSV[i][j])
            policys.append(nP)
        print(np.corrcoef(policys,ratesrestricted))

#comparing similar cities yield higher negative correlation for most policies
print('Looking at rate of black homicides')
lookAtCities(['Los Angeles','San Francisco','Philadelphia','Orlando'],' for Black People')
lookAtCities(['New Orleans','Baton Rouge','Orlando'],' for Black People')
print()
print('Looking at rate of white homicides')
lookAtCities(['Los Angeles','San Francisco','Philadelphia','Orlando'],'')
lookAtCities(['New Orleans','Baton Rouge','Orlando'],'')

# %% [markdown]
# Finally, I thought that maybe bucketing homicide rates based on number of policies might reveal some larger trend since I saw a graphic indicating so published by Campaign Zero, who provided the policies dataset. After doing this I realized they slightly painted the picture brighter than it was by drawing the below graph in a distorted way. It probably would have been better for them to compare similar cities to get the trend they were looking for.

# %%
import numpy as np
labels=['0 to 1','2','3','4+']
labelsn=[0,1,2,3]
lowest=0
ok=0
better=0
best=0
for row in readCSV:
    if row[0]!='City':
        nP=int(row[40])
        k=float(row[42])
        if nP<2:
            lowest=lowest+k
        elif nP==2:
            ok=ok+k
        elif nP==3:
            better=better+k
        elif nP>4:
            best=best+k
killings=[lowest,ok,better,best]
plt.plot(labels,killings)
np.corrcoef(labelsn,killings)
# Out:
# array([[ 1.        , -0.39469219],
#        [-0.39469219,  1.        ]])

# %% [markdown]
# # Part II: State Specific Data Analysis

# %%
import csv
#can use rate of death estimates to estimate p-values?

#read csv
with open('states.csv') as csvfile:
    csvthing = csv.reader(csvfile, delimiter=',')
    total=0
    count=0
    readCSV=[]
    for row in csvthing:
        readCSV.append(row)

    #dictify row 1
    querydict={}
    labels=readCSV[0]
    for el in labels:
        name=el
        querydict[name]=count
        count=count+1
    count=0

    #dictify column 1
    statedict={}
    for row in readCSV:
        if row[0]!='State':
            state=row[0]
            statedict[state]=count
            count=count+1
    count=0
    
    print(statedict)
    print(querydict)
# Out:
# {'Alabama': 0, 'Alaska': 1, 'Arizona': 2, 'Arkansas': 3, 'California': 4, 'Colorado': 5, 'Connecticut': 6, 'Delaware': 7, 'District of Columbia': 8, 'Florida': 9, 'Georgia': 10, 'Hawaii': 11, 'Idaho': 12, 'Illinois': 13, 'Indiana': 14, 'Iowa': 15, 'Kansas': 16, 'Kentucky': 17, 'Louisiana': 18, 'Maine': 19, 'Maryland': 20, 'Massachusetts': 21, 'Michigan': 22, 'Minnesota': 23, 'Mississippi': 24, 'Missouri': 25, 'Montana': 26, 'Nebraska': 27, 'Nevada': 28, 'New Hampshire': 29, 'New Jersey': 30, 'New Mexico': 31, 'New York': 32, 'North Carolina': 33, 'North Dakota': 34, 'Ohio': 35, 'Oklahoma': 36, 'Oregon': 37, 'Pennsylvania': 38, 'Rhode Island': 39, 'South Carolina': 40, 'South Dakota': 41, 'Tennessee': 42, 'Texas': 43, 'Utah': 44, 'Vermont': 45, 'Virginia': 46, 'Washington': 47, 'West Virginia': 48, 'Wisconsin': 49, 'Wyoming': 50}
# {'State': 0, 'Population': 1, 'African-American Alone': 2, '% African-American': 3, '% Victims Black': 4, 'Disparity': 5, '# Black people killed': 6, '# Hispanic people killed': 7, '# Native American people killed': 8, '# Asian people killed': 9, '# Pacific Islanders killed': 10, '# White people killed': 11, '# Unknown Race people killed': 12, '# People Killed': 13, 'Rate (Black People)': 14, 'Rate (All People)': 15, '0': 16, '% white': 17}

# %% [markdown]
# ## Ex.1 Alabama

# %% [markdown]
# We can look at the state of Alabama as an example before algorithmically analyzing all of the states. I used bayesian probability to derive how to calculate the rate of police homicide given race in a given state. The derivation of this (and thus all following formulas) is shown on my github using Bayes theoerem. Then using this probability and assuming a Poisson distribution(a probability distribution where something happens at a rate) I calculated the rate of homicide. This revealed significant racial disparities. Also if these numbers sound very large, it's important to remember these homicides include armed victims.

# %%
pb1=float(readCSV[statedict['Alabama']+1][6])/float(readCSV[statedict['Alabama']+1][2].replace(',',''))
print('the probability that someone is killed by an officer given theyre black is',pb1)
#calculating lambda=p*n
print('the rate of killing per 100k is thus',(pb1*100000))
rate1=pb1*100000

whitepop=float(readCSV[statedict['Alabama']+1][17])*int(readCSV[statedict['Alabama']+1][1].replace(',', ''))
pb2=float(readCSV[statedict['Alabama']+1][11])/(whitepop)
print('the probability that someone is killed by an officer given theyre white is',pb2)
#calculating lambda=p*n
print('the rate of killing per 100k is thus',pb2*100000)
rate2=pb2*100000

pb3=(float(readCSV[statedict['Alabama']+1][6])+float(readCSV[statedict['Alabama']+1][7])
    +float(readCSV[statedict['Alabama']+1][8])+float(readCSV[statedict['Alabama']+1][9])
    +float(readCSV[statedict['Alabama']+1][10]))/(int(readCSV[statedict['Alabama']+1][1].replace(',', ''))-whitepop)
print('the probability that someone is killed by an officer given theyre not white is',pb3)
#calculating lambda=p*n
print('the rate of killing per 100k is thus',pb3*100000)
rate3=pb3*100000

bwdisparity =rate1-rate2
print('the black-white disparity is ',bwdisparity)

disparity=rate3-rate2
print('the disparity is ',disparity)
# Out:
# the probability that someone is killed by an officer given theyre black is 3.915893011409634e-05
# the rate of killing per 100k is thus 3.9158930114096338
# the probability that someone is killed by an officer given theyre white is 2.250663165826681e-05
# the rate of killing per 100k is thus 2.250663165826681
# the probability that someone is killed by an officer given theyre not white is 3.0767143526213957e-05
# the rate of killing per 100k is thus 3.0767143526213956
# the black-white disparity is  1.6652298455829526
# the disparity is  0.8260511867947145

# %% [markdown]
# ## Ex.2 Iterating Through States

# %%
disparities=[]
for state in statedict.keys():
    print("")
    pb1=float(readCSV[statedict[state]+1][6])/float(readCSV[statedict[state]+1][2].replace(',', ''))
    print('the probability that someone is killed by an officer in',state,'given theyre black is',pb1)
    rate1=pb1*100000
    print('the rate of killing per 100k is thus',rate1)
    
    whitepop=float(readCSV[statedict[state]+1][17])*int(readCSV[statedict[state]+1][1].replace(',', ''))
    pb2=float(readCSV[statedict[state]+1][11])/(whitepop)
    print('the probability that someone is killed by an officer',state,'given theyre white is',pb2)
    rate2=pb2*100000
    print('the rate of killing per 100k is thus',rate2)
    
    pb3=(float(readCSV[statedict[state]+1][6])+float(readCSV[statedict[state]+1][7])
    +float(readCSV[statedict[state]+1][8])+float(readCSV[statedict[state]+1][9])
    +float(readCSV[statedict[state]+1][10]))/(int(readCSV[statedict[state]+1][1].replace(',', ''))-whitepop)
    print('the probability that someone is killed by an officer given theyre not white is',pb3)
    print('the rate of killing per 100k is thus',pb3*100000)
    rate3=pb3*100000
    
    bwdisparity =rate1-rate2
    print('the black-white disparity is ',bwdisparity)
    disparity=rate3-rate2
    disparities.append(disparity)
    print('the disparity is ',disparity)
    print("")
# Out:
# the probability that someone is killed by an officer in Alabama given theyre black is 3.915893011409634e-05
# the rate of killing per 100k is thus 3.9158930114096338
# the probability that someone is killed by an officer Alabama given theyre white is 2.250663165826681e-05
# the rate of killing per 100k is thus 2.250663165826681
# the probability that someone is killed by an officer given theyre not white is 3.0767143526213957e-05
# the rate of killing per 100k is thus 3.0767143526213956
# the black-white disparity is  1.6652298455829526
# the disparity is  0.8260511867947145
#
#
# the probability that someone is killed by an officer in Alaska given theyre black is 0.00017194686841765893
# the rate of killing per 100k is thus 17.194686841765893
# the probability that someone is killed by an officer Alaska given theyre white is 3.0006399903462487e-05
# the rate of killing per 100k is thus 3.0006399903462486
# the probability that someone is killed by an officer given theyre not white is 6.137403688341341e-05
# the rate of killing per 100k is thus 6.137403688341341
# the black-white disparity is  14.194046851419644
# the disparity is  3.1367636979950926
#
#
# the probability that someone is killed by an officer in Arizona given theyre black is 0.00010810476896466518
# the rate of killing per 100k is thus 10.810476896466518
# the probability that someone is killed by an officer Arizona given theyre white is 3.811572522982395e-05
# the rate of killing per 100k is thus 3.811572522982395
# the probability that someone is killed by an officer given theyre not white is 4.693354226060413e-05
# the rate of killing per 100k is thus 4.693354226060412
# the black-white disparity is  6.998904373484123
# the disparity is  0.8817817030780173
#
#
# the probability that someone is killed by an officer in Arkansas given theyre black is 5.55685215439158e-05
# the rate of killing per 100k is thus 5.5568521543915805
# the probability that someone is killed by an officer Arkansas given theyre white is 2.4898759061821148e-05
# the rate of killing per 100k is thus 2.4898759061821147
# the probability that someone is killed by an officer given theyre not white is 3.683485180564317e-05
# the rate of killing per 100k is thus 3.683485180564317
# the black-white disparity is  3.066976248209466
# the disparity is  1.1936092743822022
#
#
# the probability that someone is killed by an officer in California given theyre black is 7.394287782200819e-05
# the rate of killing per 100k is thus 7.394287782200819
# the probability that someone is killed by an officer California given theyre white is 2.2127162128079076e-05
# the rate of killing per 100k is thus 2.2127162128079076
# the probability that someone is killed by an officer given theyre not white is 2.867491356499074e-05
# the rate of killing per 100k is thus 2.867491356499074
# the black-white disparity is  5.181571569392911
# the disparity is  0.6547751436911664
#
#
# the probability that someone is killed by an officer in Colorado given theyre black is 7.931118238102084e-05
# the rate of killing per 100k is thus 7.9311182381020835
# the probability that someone is killed by an officer Colorado given theyre white is 2.4562457252552072e-05
# the rate of killing per 100k is thus 2.456245725255207
# the probability that someone is killed by an officer given theyre not white is 4.9709734915879205e-05
# the rate of killing per 100k is thus 4.9709734915879205
# the black-white disparity is  5.4748725128468765
# the disparity is  2.5147277663327134
#
#
# the probability that someone is killed by an officer in Connecticut given theyre black is 1.3800870006845232e-05
# the rate of killing per 100k is thus 1.3800870006845232
# the probability that someone is killed by an officer Connecticut given theyre white is 7.516771828462138e-06
# the rate of killing per 100k is thus 0.7516771828462139
# the probability that someone is killed by an officer given theyre not white is 9.326365046425248e-06
# the rate of killing per 100k is thus 0.9326365046425248
# the black-white disparity is  0.6284098178383093
# the disparity is  0.1809593217963109
#
#
# the probability that someone is killed by an officer in Delaware given theyre black is 4.692045418999656e-05
# the rate of killing per 100k is thus 4.692045418999656
# the probability that someone is killed by an officer Delaware given theyre white is 1.5909537099290464e-05
# the rate of killing per 100k is thus 1.5909537099290465
# the probability that someone is killed by an officer given theyre not white is 2.70892118177108e-05
# the rate of killing per 100k is thus 2.70892118177108
# the black-white disparity is  3.101091709070609
# the disparity is  1.1179674718420336
#
#
# the probability that someone is killed by an officer in District of Columbia given theyre black is 7.333333333333333e-05
# the rate of killing per 100k is thus 7.333333333333333
# the probability that someone is killed by an officer District of Columbia given theyre white is 4.616372945321648e-06
# the rate of killing per 100k is thus 0.4616372945321648
# the probability that someone is killed by an officer given theyre not white is 5.71276151983554e-05
# the rate of killing per 100k is thus 5.7127615198355395
# the black-white disparity is  6.8716960388011685
# the disparity is  5.251124225303375
#
#
# the probability that someone is killed by an officer in Florida given theyre black is 5.500253011638535e-05
# the rate of killing per 100k is thus 5.500253011638535
# the probability that someone is killed by an officer Florida given theyre white is 2.1964584540277403e-05
# the rate of killing per 100k is thus 2.1964584540277405
# the probability that someone is killed by an officer given theyre not white is 2.8328275830363626e-05
# the rate of killing per 100k is thus 2.8328275830363627
# the black-white disparity is  3.3037945576107948
# the disparity is  0.6363691290086222
#
#
# the probability that someone is killed by an officer in Georgia given theyre black is 2.888490002174303e-05
# the rate of killing per 100k is thus 2.888490002174303
# the probability that someone is killed by an officer Georgia given theyre white is 1.8891971866098868e-05
# the rate of killing per 100k is thus 1.889197186609887
# the probability that someone is killed by an officer given theyre not white is 2.2401842489170978e-05
# the rate of killing per 100k is thus 2.2401842489170978
# the black-white disparity is  0.9992928155644161
# the disparity is  0.3509870623072109
#
#
# the probability that someone is killed by an officer in Hawaii given theyre black is 4.667662434652726e-05
# the rate of killing per 100k is thus 4.667662434652726
# the probability that someone is killed by an officer Hawaii given theyre white is 2.8005006314953897e-05
# the rate of killing per 100k is thus 2.8005006314953897
# the probability that someone is killed by an officer given theyre not white is 2.1402560205890394e-05
# the rate of killing per 100k is thus 2.1402560205890393
# the black-white disparity is  1.8671618031573365
# the disparity is  -0.6602446109063504
#
#
# the probability that someone is killed by an officer in Idaho given theyre black is 0.00010193679918450561
# the rate of killing per 100k is thus 10.193679918450561
# the probability that someone is killed by an officer Idaho given theyre white is 2.3338725408724096e-05
# the rate of killing per 100k is thus 2.3338725408724095
# the probability that someone is killed by an officer given theyre not white is 3.544028673176622e-05
# the rate of killing per 100k is thus 3.544028673176622
# the black-white disparity is  7.859807377578152
# the disparity is  1.2101561323042125
#
#
# the probability that someone is killed by an officer in Illinois given theyre black is 4.7685025937439386e-05
# the rate of killing per 100k is thus 4.768502593743938
# the probability that someone is killed by an officer Illinois given theyre white is 6.643936295526539e-06
# the rate of killing per 100k is thus 0.6643936295526539
# the probability that someone is killed by an officer given theyre not white is 2.1982649182930506e-05
# the rate of killing per 100k is thus 2.1982649182930505
# the black-white disparity is  4.104108964191284
# the disparity is  1.5338712887403965
#
#
# the probability that someone is killed by an officer in Indiana given theyre black is 5.918190318855185e-05
# the rate of killing per 100k is thus 5.918190318855185
# the probability that someone is killed by an officer Indiana given theyre white is 1.2689850956685325e-05
# the rate of killing per 100k is thus 1.2689850956685325
# the probability that someone is killed by an officer given theyre not white is 3.084609924855818e-05
# the rate of killing per 100k is thus 3.084609924855818
# the black-white disparity is  4.6492052231866525
# the disparity is  1.8156248291872856
#
#
# the probability that someone is killed by an officer in Iowa given theyre black is 5.6086507829676495e-05
# the rate of killing per 100k is thus 5.60865078296765
# the probability that someone is killed by an officer Iowa given theyre white is 1.1832669412431243e-05
# the rate of killing per 100k is thus 1.1832669412431243
# the probability that someone is killed by an officer given theyre not white is 1.6413057572082037e-05
# the rate of killing per 100k is thus 1.6413057572082037
# the black-white disparity is  4.425383841724526
# the disparity is  0.45803881596507945
#
#
# the probability that someone is killed by an officer in Kansas given theyre black is 7.74436448553591e-05
# the rate of killing per 100k is thus 7.74436448553591
# the probability that someone is killed by an officer Kansas given theyre white is 1.9369390924152746e-05
# the rate of killing per 100k is thus 1.9369390924152747
# the probability that someone is killed by an officer given theyre not white is 3.212859288212639e-05
# the rate of killing per 100k is thus 3.212859288212639
# the black-white disparity is  5.807425393120635
# the disparity is  1.2759201957973643
#
#
# the probability that someone is killed by an officer in Kentucky given theyre black is 4.7404598246029865e-05
# the rate of killing per 100k is thus 4.740459824602986
# the probability that someone is killed by an officer Kentucky given theyre white is 2.2231488656132134e-05
# the rate of killing per 100k is thus 2.2231488656132132
# the probability that someone is killed by an officer given theyre not white is 3.2262770122923444e-05
# the rate of killing per 100k is thus 3.2262770122923445
# the black-white disparity is  2.517310958989773
# the disparity is  1.0031281466791313
#
#
# the probability that someone is killed by an officer in Louisiana given theyre black is 4.750770451034015e-05
# the rate of killing per 100k is thus 4.750770451034016
# the probability that someone is killed by an officer Louisiana given theyre white is 1.7572133270588105e-05
# the rate of killing per 100k is thus 1.7572133270588104
# the probability that someone is killed by an officer given theyre not white is 4.196520877594523e-05
# the rate of killing per 100k is thus 4.196520877594523
# the black-white disparity is  2.9935571239752052
# the disparity is  2.4393075505357125
#
#
# the probability that someone is killed by an officer in Maine given theyre black is 6.366588145412873e-05
# the rate of killing per 100k is thus 6.366588145412873
# the probability that someone is killed by an officer Maine given theyre white is 2.002147359102764e-05
# the rate of killing per 100k is thus 2.0021473591027643
# the probability that someone is killed by an officer given theyre not white is 1.2546790117043962e-05
# the rate of killing per 100k is thus 1.2546790117043962
# the black-white disparity is  4.364440786310109
# the disparity is  -0.7474683473983681
#
#
# the probability that someone is killed by an officer in Maryland given theyre black is 4.3521782652217434e-05
# the rate of killing per 100k is thus 4.352178265221744
# the probability that someone is killed by an officer Maryland given theyre white is 9.509217338704791e-06
# the rate of killing per 100k is thus 0.9509217338704791
# the probability that someone is killed by an officer given theyre not white is 2.8631615762528786e-05
# the rate of killing per 100k is thus 2.8631615762528786
# the black-white disparity is  3.4012565313512644
# the disparity is  1.9122398423823994
#
#
# the probability that someone is killed by an officer in Massachusetts given theyre black is 3.683258210212754e-05
# the rate of killing per 100k is thus 3.6832582102127542
# the probability that someone is killed by an officer Massachusetts given theyre white is 5.939384911528874e-06
# the rate of killing per 100k is thus 0.5939384911528874
# the probability that someone is killed by an officer given theyre not white is 1.418179662548731e-05
# the rate of killing per 100k is thus 1.418179662548731
# the black-white disparity is  3.089319719059867
# the disparity is  0.8242411713958436
#
#
# the probability that someone is killed by an officer in Michigan given theyre black is 2.7849941657942733e-05
# the rate of killing per 100k is thus 2.784994165794273
# the probability that someone is killed by an officer Michigan given theyre white is 7.014959400922467e-06
# the rate of killing per 100k is thus 0.7014959400922467
# the probability that someone is killed by an officer given theyre not white is 1.861662302552501e-05
# the rate of killing per 100k is thus 1.861662302552501
# the black-white disparity is  2.0834982257020265
# the disparity is  1.1601663624602543
#
#
# the probability that someone is killed by an officer in Minnesota given theyre black is 5.101817704765098e-05
# the rate of killing per 100k is thus 5.101817704765098
# the probability that someone is killed by an officer Minnesota given theyre white is 1.084102810654374e-05
# the rate of killing per 100k is thus 1.084102810654374
# the probability that someone is killed by an officer given theyre not white is 2.5452848597972256e-05
# the rate of killing per 100k is thus 2.5452848597972255
# the black-white disparity is  4.017714894110725
# the disparity is  1.4611820491428515
#
#
# the probability that someone is killed by an officer in Mississippi given theyre black is 2.9789610873207967e-05
# the rate of killing per 100k is thus 2.978961087320797
# the probability that someone is killed by an officer Mississippi given theyre white is 2.4240857777769975e-05
# the rate of killing per 100k is thus 2.4240857777769973
# the probability that someone is killed by an officer given theyre not white is 2.6647068844763587e-05
# the rate of killing per 100k is thus 2.6647068844763586
# the black-white disparity is  0.5548753095437995
# the disparity is  0.24062110669936132
#
#
# the probability that someone is killed by an officer in Missouri given theyre black is 8.948317077223976e-05
# the rate of killing per 100k is thus 8.948317077223976
# the probability that someone is killed by an officer Missouri given theyre white is 1.6488763346088537e-05
# the rate of killing per 100k is thus 1.6488763346088537
# the probability that someone is killed by an officer given theyre not white is 5.7606312449625814e-05
# the rate of killing per 100k is thus 5.760631244962582
# the black-white disparity is  7.299440742615122
# the disparity is  4.111754910353728
#
#
# the probability that someone is killed by an officer in Montana given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer Montana given theyre white is 2.7881330782888598e-05
# the rate of killing per 100k is thus 2.7881330782888596
# the probability that someone is killed by an officer given theyre not white is 4.664761111752517e-05
# the rate of killing per 100k is thus 4.664761111752517
# the black-white disparity is  -2.7881330782888596
# the disparity is  1.8766280334636574
#
#
# the probability that someone is killed by an officer in Nebraska given theyre black is 8.445436448090728e-05
# the rate of killing per 100k is thus 8.445436448090728
# the probability that someone is killed by an officer Nebraska given theyre white is 1.4554937156321113e-05
# the rate of killing per 100k is thus 1.4554937156321113
# the probability that someone is killed by an officer given theyre not white is 2.3466123170395272e-05
# the rate of killing per 100k is thus 2.346612317039527
# the black-white disparity is  6.9899427324586165
# the disparity is  0.8911186014074157
#
#
# the probability that someone is killed by an officer in Nevada given theyre black is 8.69064063743562e-05
# the rate of killing per 100k is thus 8.69064063743562
# the probability that someone is killed by an officer Nevada given theyre white is 4.156370235525405e-05
# the rate of killing per 100k is thus 4.156370235525405
# the probability that someone is killed by an officer given theyre not white is 3.412520731698755e-05
# the rate of killing per 100k is thus 3.4125207316987547
# the black-white disparity is  4.534270401910216
# the disparity is  -0.7438495038266506
#
#
# the probability that someone is killed by an officer in New Hampshire given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer New Hampshire given theyre white is 1.1686263556796118e-05
# the rate of killing per 100k is thus 1.1686263556796117
# the probability that someone is killed by an officer given theyre not white is 8.44007923546386e-06
# the rate of killing per 100k is thus 0.844007923546386
# the black-white disparity is  -1.1686263556796117
# the disparity is  -0.3246184321332257
#
#
# the probability that someone is killed by an officer in New Jersey given theyre black is 4.149976843129215e-05
# the rate of killing per 100k is thus 4.149976843129215
# the probability that someone is killed by an officer New Jersey given theyre white is 5.997259831302871e-06
# the rate of killing per 100k is thus 0.5997259831302871
# the probability that someone is killed by an officer given theyre not white is 1.642927501678756e-05
# the rate of killing per 100k is thus 1.642927501678756
# the black-white disparity is  3.5502508599989278
# the disparity is  1.0432015185484689
#
#
# the probability that someone is killed by an officer in New Mexico given theyre black is 9.400705052878966e-05
# the rate of killing per 100k is thus 9.400705052878966
# the probability that someone is killed by an officer New Mexico given theyre white is 5.250058790814597e-05
# the rate of killing per 100k is thus 5.250058790814597
# the probability that someone is killed by an officer given theyre not white is 6.012567329480526e-05
# the rate of killing per 100k is thus 6.012567329480526
# the black-white disparity is  4.1506462620643685
# the disparity is  0.7625085386659292
#
#
# the probability that someone is killed by an officer in New York given theyre black is 2.1797124080942157e-05
# the rate of killing per 100k is thus 2.1797124080942156
# the probability that someone is killed by an officer New York given theyre white is 4.785157634492414e-06
# the rate of killing per 100k is thus 0.4785157634492414
# the probability that someone is killed by an officer given theyre not white is 1.0091574270563525e-05
# the rate of killing per 100k is thus 1.0091574270563526
# the black-white disparity is  1.7011966446449742
# the disparity is  0.5306416636071112
#
#
# the probability that someone is killed by an officer in North Carolina given theyre black is 3.6609867677294266e-05
# the rate of killing per 100k is thus 3.6609867677294265
# the probability that someone is killed by an officer North Carolina given theyre white is 1.6146875199531473e-05
# the rate of killing per 100k is thus 1.6146875199531474
# the probability that someone is killed by an officer given theyre not white is 2.4942400698301057e-05
# the rate of killing per 100k is thus 2.4942400698301057
# the black-white disparity is  2.046299247776279
# the disparity is  0.8795525498769583
#
#
# the probability that someone is killed by an officer in North Dakota given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer North Dakota given theyre white is 1.399329563714405e-05
# the rate of killing per 100k is thus 1.399329563714405
# the probability that someone is killed by an officer given theyre not white is 3.964767097190813e-05
# the rate of killing per 100k is thus 3.964767097190813
# the black-white disparity is  -1.399329563714405
# the disparity is  2.565437533476408
#
#
# the probability that someone is killed by an officer in Ohio given theyre black is 5.327911650437848e-05
# the rate of killing per 100k is thus 5.327911650437848
# the probability that someone is killed by an officer Ohio given theyre white is 1.163066516423636e-05
# the rate of killing per 100k is thus 1.163066516423636
# the probability that someone is killed by an officer given theyre not white is 3.302147521921554e-05
# the rate of killing per 100k is thus 3.302147521921554
# the black-white disparity is  4.164845134014212
# the disparity is  2.139081005497918
#
#
# the probability that someone is killed by an officer in Oklahoma given theyre black is 0.00015847632219676997
# the rate of killing per 100k is thus 15.847632219676997
# the probability that someone is killed by an officer Oklahoma given theyre white is 4.402454346487842e-05
# the rate of killing per 100k is thus 4.4024543464878425
# the probability that someone is killed by an officer given theyre not white is 5.801831362182036e-05
# the rate of killing per 100k is thus 5.801831362182036
# the black-white disparity is  11.445177873189156
# the disparity is  1.3993770156941938
#
#
# the probability that someone is killed by an officer in Oregon given theyre black is 0.00011559691356240789
# the rate of killing per 100k is thus 11.559691356240789
# the probability that someone is killed by an officer Oregon given theyre white is 2.610234101455623e-05
# the rate of killing per 100k is thus 2.6102341014556227
# the probability that someone is killed by an officer given theyre not white is 1.6313963134097647e-05
# the rate of killing per 100k is thus 1.6313963134097647
# the black-white disparity is  8.949457254785166
# the disparity is  -0.9788377880458581
#
#
# the probability that someone is killed by an officer in Pennsylvania given theyre black is 3.774436756045813e-05
# the rate of killing per 100k is thus 3.7744367560458127
# the probability that someone is killed by an officer Pennsylvania given theyre white is 7.974781834072286e-06
# the rate of killing per 100k is thus 0.7974781834072286
# the probability that someone is killed by an officer given theyre not white is 2.1906201158477276e-05
# the rate of killing per 100k is thus 2.1906201158477274
# the black-white disparity is  2.9769585726385843
# the disparity is  1.3931419324404988
#
#
# the probability that someone is killed by an officer in Rhode Island given theyre black is 4.984299456711359e-05
# the rate of killing per 100k is thus 4.984299456711359
# the probability that someone is killed by an officer Rhode Island given theyre white is 2.639050794655141e-06
# the rate of killing per 100k is thus 0.2639050794655141
# the probability that someone is killed by an officer given theyre not white is 1.357226122965501e-05
# the rate of killing per 100k is thus 1.357226122965501
# the black-white disparity is  4.720394377245845
# the disparity is  1.0933210434999867
#
#
# the probability that someone is killed by an officer in South Carolina given theyre black is 2.7117404415023352e-05
# the rate of killing per 100k is thus 2.7117404415023354
# the probability that someone is killed by an officer South Carolina given theyre white is 2.12821088243001e-05
# the rate of killing per 100k is thus 2.12821088243001
# the probability that someone is killed by an officer given theyre not white is 2.342158008176942e-05
# the rate of killing per 100k is thus 2.342158008176942
# the black-white disparity is  0.5835295590723253
# the disparity is  0.2139471257469321
#
#
# the probability that someone is killed by an officer in South Dakota given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer South Dakota given theyre white is 1.4797947347127584e-05
# the rate of killing per 100k is thus 1.4797947347127585
# the probability that someone is killed by an officer given theyre not white is 6.502392157826063e-05
# the rate of killing per 100k is thus 6.502392157826064
# the black-white disparity is  -1.4797947347127585
# the disparity is  5.0225974231133055
#
#
# the probability that someone is killed by an officer in Tennessee given theyre black is 3.220645474187948e-05
# the rate of killing per 100k is thus 3.2206454741879478
# the probability that someone is killed by an officer Tennessee given theyre white is 2.1507127046666653e-05
# the rate of killing per 100k is thus 2.1507127046666654
# the probability that someone is killed by an officer given theyre not white is 2.4848676107991865e-05
# the rate of killing per 100k is thus 2.4848676107991867
# the black-white disparity is  1.0699327695212824
# the disparity is  0.3341549061325213
#
#
# the probability that someone is killed by an officer in Texas given theyre black is 4.463689397026042e-05
# the rate of killing per 100k is thus 4.463689397026042
# the probability that someone is killed by an officer Texas given theyre white is 2.1020466736511807e-05
# the rate of killing per 100k is thus 2.1020466736511807
# the probability that someone is killed by an officer given theyre not white is 2.2832575937935236e-05
# the rate of killing per 100k is thus 2.2832575937935236
# the black-white disparity is  2.361642723374861
# the disparity is  0.18121092014234286
#
#
# the probability that someone is killed by an officer in Utah given theyre black is 0.00023901389695086557
# the rate of killing per 100k is thus 23.901389695086557
# the probability that someone is killed by an officer Utah given theyre white is 2.2441352102455855e-05
# the rate of killing per 100k is thus 2.2441352102455854
# the probability that someone is killed by an officer given theyre not white is 3.618095543049005e-05
# the rate of killing per 100k is thus 3.618095543049005
# the black-white disparity is  21.657254484840973
# the disparity is  1.3739603328034198
#
#
# the probability that someone is killed by an officer in Vermont given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer Vermont given theyre white is 1.0310356686274044e-05
# the rate of killing per 100k is thus 1.0310356686274045
# the probability that someone is killed by an officer given theyre not white is 4.566015103921363e-05
# the rate of killing per 100k is thus 4.566015103921362
# the black-white disparity is  -1.0310356686274045
# the disparity is  3.534979435293958
#
#
# the probability that someone is killed by an officer in Virginia given theyre black is 3.351813427751339e-05
# the rate of killing per 100k is thus 3.351813427751339
# the probability that someone is killed by an officer Virginia given theyre white is 9.273006603541843e-06
# the rate of killing per 100k is thus 0.9273006603541843
# the probability that someone is killed by an officer given theyre not white is 2.0063221381347398e-05
# the rate of killing per 100k is thus 2.0063221381347396
# the black-white disparity is  2.4245127673971547
# the disparity is  1.0790214777805551
#
#
# the probability that someone is killed by an officer in Washington given theyre black is 8.33187525516368e-05
# the rate of killing per 100k is thus 8.33187525516368
# the probability that someone is killed by an officer Washington given theyre white is 2.219859831584623e-05
# the rate of killing per 100k is thus 2.219859831584623
# the probability that someone is killed by an officer given theyre not white is 2.8302691432449098e-05
# the rate of killing per 100k is thus 2.8302691432449096
# the black-white disparity is  6.112015423579058
# the disparity is  0.6104093116602867
#
#
# the probability that someone is killed by an officer in West Virginia given theyre black is 0.00014257651606362082
# the rate of killing per 100k is thus 14.257651606362082
# the probability that someone is killed by an officer West Virginia given theyre white is 2.3791777796029745e-05
# the rate of killing per 100k is thus 2.3791777796029745
# the probability that someone is killed by an officer given theyre not white is 6.938577705671402e-05
# the rate of killing per 100k is thus 6.938577705671402
# the black-white disparity is  11.878473826759107
# the disparity is  4.559399926068427
#
#
# the probability that someone is killed by an officer in Wisconsin given theyre black is 6.682481873767917e-05
# the rate of killing per 100k is thus 6.682481873767917
# the probability that someone is killed by an officer Wisconsin given theyre white is 1.1365272631489408e-05
# the rate of killing per 100k is thus 1.1365272631489407
# the probability that someone is killed by an officer given theyre not white is 3.516801342574079e-05
# the rate of killing per 100k is thus 3.516801342574079
# the black-white disparity is  5.545954610618976
# the disparity is  2.3802740794251385
#
#
# the probability that someone is killed by an officer in Wyoming given theyre black is 0.0
# the rate of killing per 100k is thus 0.0
# the probability that someone is killed by an officer Wyoming given theyre white is 2.534608816079153e-05
# the rate of killing per 100k is thus 2.534608816079153
# the probability that someone is killed by an officer given theyre not white is 3.326674071103887e-05
# the rate of killing per 100k is thus 3.326674071103887
# the black-white disparity is  -2.534608816079153
# the disparity is  0.7920652550247338

# %%
avg=np.sum(disparities)/len(disparities)
print('national disparity is',avg)
# Out:
# national disparity is 1.3214192025732312

# %% [markdown]
# # Part III: Aggregate Data and Joint Sampling

# %%
with open('aggregate.csv') as csvfile:
    csvthing = csv.reader(csvfile, delimiter=',')
    total=0
    count=0
    readCSV=[]
    for row in csvthing:
        readCSV.append(row)
        
#dictify row 1
    querydict={}
    labels=readCSV[0]
    for el in labels:
        name=el
        querydict[name]=count
        count=count+1
    count=0

    print(querydict)
# Out:
# {"\ufeffVictim's name": 0, "Victim's age": 1, "Victim's gender": 2, "Victim's race": 3, 'URL of image of victim': 4, 'Date of Incident (month/day/year)': 5, 'Street Address of Incident': 6, 'City': 7, 'State': 8, 'Zipcode': 9, 'County': 10, 'Agency responsible for death': 11, 'Cause of death': 12, 'A brief description of the circumstances surrounding the death': 13, 'Official disposition of death (justified or other)': 14, 'Criminal Charges?': 15, 'Link to news article or photo of official document': 16, 'Symptoms of mental illness?': 17, 'Unarmed': 18, 'Alleged Weapon (Source: WaPo)': 19, 'Alleged Threat Level (Source: WaPo)': 20, 'Fleeing (Source: WaPo)': 21, 'Body Camera (Source: WaPo)': 22, 'WaPo ID (If included in WaPo database)': 23}

# %%
##### n=1000000
wcount=0
for row in readCSV:
        if row[3]=='White' or row[3]=='white':
            wcount=wcount+1
            
bcount=0
for row in readCSV:
        if row[3]=='Black' or row[3]=='black':
            bcount=bcount+1

ncount=0
for row in readCSV:
        if row[3]=='Unknown Race' or row[3]=='?':
            ncount=ncount+1
tcount=len(readCSV)-1

#prob of police homicide
probPoliceHomicide= tcount/327000000 #P(H)
ratePoliceHomicide=n*probPoliceHomicide 

#prob of police homicide involving someone white
probWHomicide= wcount/327000000 #P(W,H)
rateWHomicide=n*probWHomicide
probHomicidegW=probWHomicide/(0.607) #P(H|W)
rateHomicidegW=n*probHomicidegW

#prob of shooting someone black
probBHomicide= bcount/327000000 #P(B,H)
rateBHomicide=n*probBHomicide
probHomicidegB=probBHomicide/(0.14) #P(B|H)
rateHomicidegB=n*probHomicidegB

print(rateHomicidegW,'police homicides of white people per million in America')
print(rateHomicidegB,'police homicides of black people per million in America')


#prob of police homicide involving someone black and unarmed
ucount=0
for row in readCSV:
    if row[18]=='Unarmed' or row[18]=='unarmed':
        ucount=ucount+1
probUH=ucount/327000000

probHgU=probUH/probPoliceHomicide

ucount=0
for row in readCSV:
    if (row[18]=='Unarmed' or row[18]=='unarmed') and (row[3]=='Black' or row[3]=='black'):
        ucount=ucount+1
probBUH=ucount/327000000

probBgUH=probBUH/probHgU

ucount=0
for row in readCSV:
    if row[18]=='Armed' or row[18]=='Allegedly Armed':
        ucount=ucount+1
probAH=ucount/327000000

ucount=0
for row in readCSV:
    if (row[18]=='Armed' or row[18]=='Allegedly Armed') and (row[3]=='Black' or row[3]=='black'):
        ucount=ucount+1
probBAH=ucount/327000000

probHgA=probAH/probPoliceHomicide
probBgAH=probBAH/probHgA

probB=.14
probU=.99 # approximated, 3 million Americans carry guns daily, more probably carry occasionally/illegally
#this data obviously doesn't exist, so i had to make a generous guess

probBgU=probB*probU

probHgBU=(probBgUH*probHgU)/probBgU
print('probability of a police homicide, given a black unarmed victim is',probHgBU)
print(probHgBU*1000000,'per million')


#prob of police homicide involving someone white and unarmed
ucount=0
for row in readCSV:
    if (row[18]=='Unarmed' or row[18]=='unarmed') and (row[3]=='White' or row[3]=='white'):
        ucount=ucount+1
probWUH=ucount/327000000

probWgUH=probWUH/probHgU

ucount=0
for row in readCSV:
    if (row[18]=='Armed' or row[18]=='Allegedly Armed') and (row[3]=='White' or row[3]=='white'):
        ucount=ucount+1
probWAH=ucount/327000000

probWgAH=probWAH/probHgA

probW=.613

probWgU=probW*probU

probHgWU=(probWgUH*probHgU)/probWgU
print('probability of a police homicide, given a white unarmed victim is',probHgWU)
print(probHgWU*1000000,'per million')

print('the disparity is now even larger as the rate of murder is around 4 times larger for unarmed black people')
# Out:
# 15.517232692995579 police homicides of white people per million in America
# 38.663171690694625 police homicides of black people per million in America
# probability of a police homicide, given a black unarmed victim is 8.031384178173169e-06
# 8.03138417817317 per million
# probability of a police homicide, given a white unarmed victim is 2.232339811099707e-06
# 2.232339811099707 per million
# the disparity is now even larger as the rate of murder is around 4 times larger for unarmed black people

# %% [markdown]
# We can visualize these distributions:

# %%
from scipy.stats import poisson

w=poisson(3.27)
b=poisson(15)
arr=[]
for num in range(-5,35):
    arr.append(w.pmf(num))
prob1 = w.pmf(5)
plt.grid(True)
plt.ylabel('Probability ')
plt.xlabel('# of Annual Homicides of Unarmed People')
plt.title('Probability Distribution Curve')
plt.plot(arr, linewidth=2.0)

arr2=[]
for num in range(-5,35):
    arr2.append(b.pmf(num))
prob2 = b.pmf(12)
plt.grid(True)
plt.plot(arr2, linewidth=2.0)

# %%
probHgB=probHomicidegB
probHgW=probHomicidegW
probHgBA=probHgB-probHgBU
probHgWA=probHgW-probHgWU

def probHomicide(b,w,u):
    if u==1:
        if b==1:
            return probHgBU
        elif w==1:
            return probHgWU
        else:
            return probHgU
    else:
        if b==1:
            return probHgBA
        elif w==1:
            return probHgWA
        else:
            return probHgA

counter=0
for row in readCSV:
    if ("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14])):
        counter=counter+1
pCH=counter/327000000
probCgH=pCH/probPoliceHomicide
print(probCgH, 'is the probability that an officer is charged with homicide given a police homicide')

#assumes homicide occurs, since makeSample only runs this if homicide=1
for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='Black' or row[3]=='black') and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probCBUH=counter/327000000

for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='White' or row[3]=='white') and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probCWUH=counter/327000000

for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probCUH=counter/327000000

for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='Black' or row[3]=='black') and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probCBAH=counter/327000000

for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='White' or row[3]=='white') and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probCWAH=counter/327000000

for row in readCSV:
    c=("Charged" in str(row[14])) or ("indicted" in str(row[14])) or ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probCAH=counter/327000000

probCgBUH=probCBUH/(probBUH)#need to have homicide in the denominator as it's implied in the numerator
probCgWUH=probCWUH/(probWUH)
probCgUH=probCUH/probUH

probCgBAH=probCBAH/(probBAH)
probCgWAH=probCWAH/(probWAH)
probCgAH=probCAH/probAH

#again assumes homicide occurs, since makeSample only runs this if homicide=1
def probCharges(black,white,unarmed):
    counter=0
    if unarmed==1:
        #P(C|B=1,W=0,U=1)=P(C,B=1,W=0,U=1)/P(B=1,W=0,U=1)
        if black==1:
            return probCgBUH
        #P(C,B=0,W=1,U=1)/P(B=0,W=1,U=1)
        elif white==1:
            return probCgWUH
        #P(C,B=0,W=0,U=1)/P(B=0,W=0,U=1)
        else:
            return probCgUH
    else:
        #P(C,B=1,W=0,U=0)/P(B=1,W=0,U=0)
        if black==1:
            return probCgBAH
        #P(C,B=0,W=1,U=0)/P(B=0,W=1,U=0)
        elif white==1:
            return probCgWAH
        #P(C,B=0,W=0,U=0)/P(B=0,W=0,U=0)
        else:
            return probCgAH
# Out:
# 0.019455822118197776 is the probability that an officer is charged with homicide given a police homicide

# %%
print(probCgBUH, 'is the probability of an officer being charged given they shot someone black and unarmed')
print(probCgWUH, 'is the probability of an officer being charged given they shot someone white and unarmed')
# Out:
# 0.4697802197802198 is the probability of an officer being charged given they shot someone black and unarmed
# 0.471783295711061 is the probability of an officer being charged given they shot someone white and unarmed

# %%
#prob conviction
counter=0
for row in readCSV:
    if ("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14])):
        counter=counter+1
pVH=counter/327000000
probVgH=pVH/probPoliceHomicide
print(probVgH, 'is the probability that an officer is convicted of homicide given a police homicide')

#assumes homicide occurs, since makeSample only runs this if homicide=1
for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='Black' or row[3]=='black') and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probVCBUH=counter/327000000

for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='White' or row[3]=='white') and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probVCWUH=counter/327000000

for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[18]=='Unarmed' or row[18]=='unarmed'):
        counter=counter+1
probVCUH=counter/327000000

for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='Black' or row[3]=='black') and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probVCBAH=counter/327000000

for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[3]=='White' or row[3]=='white') and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probVCWAH=counter/327000000

for row in readCSV:
    c=("Murder" in str(row[14])) or ("Criminal" in str(row[14])) or ("Convicted" in str(row[14]))
    if c and (row[18]=='Allegedly Armed' or row[18]=='Armed'):
        counter=counter+1
probVCAH=counter/327000000

probVgCBUH=probVCBUH/(probCBUH)#need to have homicide in the denominator as it's implied in the numerator
probVgCWUH=probVCWUH/(probCWUH)
probVgCUH=probVCUH/probUH

probVgCBAH=probVCBAH/(probCBAH)
probVgCWAH=probVCWAH/(probCWAH)
probVgCAH=probVCAH/probCAH

#again assumes homicide occurs, since makeSample only runs this if homicide=1
def probConviction(black,white,unarmed):
    counter=0
    if unarmed==1:
        #P(C|B=1,W=0,U=1)=P(C,B=1,W=0,U=1)/P(B=1,W=0,U=1)
        if black==1:
            return probVgCBUH
        #P(C,B=0,W=1,U=1)/P(B=0,W=1,U=1)
        elif white==1:
            return probVgCWUH
        #P(C,B=0,W=0,U=1)/P(B=0,W=0,U=1)
        else:
            return probVgCUH
    else:
        #P(C,B=1,W=0,U=0)/P(B=1,W=0,U=0)
        if black==1:
            return probVgCBAH
        #P(C,B=0,W=1,U=0)/P(B=0,W=1,U=0)
        elif white==1:
            return probVgCWAH
        #P(C,B=0,W=0,U=0)/P(B=0,W=0,U=0)
        else:
            return probVgCAH
# Out:
# 0.008777062609713282 is the probability that an officer is convicted of homicide given a police homicide

# %%
print(probVgCBUH, 'is the probability of an officer being convicted given they shot someone black and unarmed')
print(probVgCWUH, 'is the probability of an officer being convicted given they shot someone white and unarmed')
# Out:
# 0.4327485380116959 is the probability of an officer being convicted given they shot someone black and unarmed
# 0.4736842105263158 is the probability of an officer being convicted given they shot someone white and unarmed

# %% [markdown]
# It becomes very difficult to model with different parameters after the addition of the charges event, so we need some way to model this Bayesian network of events. Joint sampling works well.

# %%
import random

# joint sampling 
def bern(p):
    event = random.random() < p
    if event: return 1
    else: return 0
    
def makeSample():
    observation=[]
    unarmed = bern(0.99)
    black = bern(0.14)
    if black!=1:
        white=bern(.613)
    else:
        white=0
    homicide=bern(probHomicide(black,white,unarmed))
    if homicide==1:
        charges=bern(probCharges(black,white,unarmed))
    else:
        charges=0
    if charges==1:
        conviction=probConviction(black,white,unarmed)
    else:
        conviction=0
    observation = [unarmed,black,white,homicide,charges,conviction]
    return observation
    
def makeSamples(n):
    samples=[]
    for i in range(n):
        samples.append(makeSample())
    return samples        

samples=makeSamples(100000000)

# %%
def probFlu(): #P(C|)
    samples=makeSamples(10000)
    keptsamples = []
    for s in samples:
        if (s[4]==0 and s[1]==1):
            keptsamples.append(s)
    total = len(keptsamples)
    count=0
    for s in keptsamples:
        if s[2]==0:
            count=count+1
    return count/total

print(prob)
# Out:
# 0.09052841713016468

# %% [markdown]
# # FUTURE WORK

# %% [markdown]
# # P-values?

# %%
# we can now calcualte p-values for a national disparity?
# that would require two generated samples of b/w populations
# and drawing out 
import random
def pvalue(universalSample,hopes):
    s=universalSample
    n=wcount
    m=tcount-wcount
    count=0
    for i in range(10000):
        r1=random.choices(s,k=n)
        sum1=0
        for i in r1:
            sum1=sum1+int(i)
        r2=random.choices(s,k=m)
        sum2=0
        for i in r2:
            sum2=sum2+int(i)
        rate1=sum1/float(n)
        rate2=sum2/float(m)
        ratediff=abs(rate1-rate2)
        if ratediff>hopes:
            count=count+1
    return count/10000

print(pvalue(np.ones(tcount),13.214192025732315))
# Out:
# 0.0

# %% [markdown]
# # Creating a GUI for a Probability Calculator

# %%
import PySimpleGUI as sg

layout = [ [sg.Txt('Enter values to calculate')],      
           [sg.In(size=(8,1), key='numerator')],      
           [sg.Txt('_'  * 10)],      
           [sg.In(size=(8,1), key='denominator')],      
           [sg.Txt('', size=(8,1), key='output')  ],      
           [sg.Button('Calculate', bind_return_key=True)]]

window = sg.Window('Math', layout)

while True:      
    event, values = window.Read()

    if event is not None:      
        try:      
            numerator = float(values['numerator'])      
            denominator = float(values['denominator'])      
            calc = numerator / denominator      
        except:      
            calc = 'Invalid'

        window.Element('output').Update(calc)      
    else:      
        break
